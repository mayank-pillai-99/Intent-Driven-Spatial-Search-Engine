# %%
# !pip install streamlit osmnx sqlalchemy psycopg2-binary geoalchemy2 geopandas langchain-groq langchain-community langchain transformers torch accelerate bitsandbytes -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 108.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 119.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 103.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 112.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 7.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
# Install Postgres and the PostGIS spatial extension
# !apt-get update
# !apt-get install -y postgresql postgresql-contrib postgis

# Start the database server
# !service postgresql start

# Set up the 'postgres' user password and create 'pilani_db'
# !sudo -u postgres psql -c "ALTER USER postgres PASSWORD 'postgres';"
# !sudo -u postgres createdb pilani_db
# !sudo -u postgres psql -d pilani_db -c "CREATE EXTENSION postgis;"
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [99.9 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,764 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,258 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,307 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,046 kB]
# Hit:16 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:18 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.6 kB]
# Get:19 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.4 MB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,526 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,612 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,379 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.8 kB]
# Get:25 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,081 kB]
# Fetched 43.1 MB in 7s (5,845 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libboost-serialization1.74.0 libcommon-sense-perl libgmpxx4ldbl libjson-perl
#   libjson-xs-perl libllvm14 libprotobuf-c1 libsfcgal1 libtypes-serialiser-perl
#   logrotate netbase postgis-doc postgresql-14 postgresql-14-postgis-3
#   postgresql-14-postgis-3-scripts postgresql-client-14
#   postgresql-client-common postgresql-common postgresql-postgis
#   postgresql-postgis-scripts ssl-cert sysstat
# Suggested packages:
#   bsd-mailx | mailx postgresql-doc postgresql-doc-14 isag
# The following NEW packages will be installed:
#   libboost-serialization1.74.0 libcommon-sense-perl libgmpxx4ldbl libjson-perl
#   libjson-xs-perl libllvm14 libprotobuf-c1 libsfcgal1 libtypes-serialiser-perl
#   logrotate netbase postgis postgis-doc postgresql postgresql-14
#   postgresql-14-postgis-3 postgresql-14-postgis-3-scripts postgresql-client-14
#   postgresql-client-common postgresql-common postgresql-contrib
#   postgresql-postgis postgresql-postgis-scripts ssl-cert sysstat
# 0 upgraded, 25 newly installed, 0 to remove and 105 not upgraded.
# Need to get 53.1 MB of archives.
# After this operation, 235 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 logrotate amd64 3.19.0-1ubuntu1.1 [54.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 netbase all 6.3 [12.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-serialization1.74.0 amd64 1.74.0-14ubuntu3 [327 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcommon-sense-perl amd64 3.75-2build1 [21.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgmpxx4ldbl amd64 2:6.2.1+dfsg-3ubuntu1 [9,580 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-perl all 4.04000-1 [81.8 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtypes-serialiser-perl all 1.01-1 [11.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libjson-xs-perl amd64 4.040-0ubuntu0.22.04.1 [87.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libllvm14 amd64 1:14.0.0-1ubuntu1.1 [24.0 MB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libprotobuf-c1 amd64 1.3.3-1ubuntu2.1 [20.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsfcgal1 amd64 1.4.1-1 [2,179 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 postgresql-client-common all 238 [29.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 postgresql-client-14 amd64 14.23-0ubuntu0.22.04.1 [1,251 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 ssl-cert all 1.1.2 [17.4 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 postgresql-common all 238 [169 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 postgresql-14 amd64 14.23-0ubuntu0.22.04.1 [16.3 MB]
# Get:17 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 postgis amd64 3.4.1+dfsg-1~jammy0 [177 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 postgresql all 14+238 [3,288 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 postgresql-contrib all 14+238 [3,292 B]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 sysstat amd64 12.5.2-2ubuntu0.2 [487 kB]
# Get:21 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 postgis-doc all 3.4.1+dfsg-1~jammy0 [2,934 kB]
# Get:22 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 postgresql-14-postgis-3-scripts all 3.4.1+dfsg-1~jammy0 [1,023 kB]
# Get:23 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 postgresql-14-postgis-3 amd64 3.4.1+dfsg-1~jammy0 [3,878 kB]
# Get:24 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 postgresql-postgis-scripts all 3.4.1+dfsg-1~jammy0 [37.2 kB]
# Get:25 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 postgresql-postgis amd64 3.4.1+dfsg-1~jammy0 [37.2 kB]
# Fetched 53.1 MB in 3s (16.7 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package logrotate.
# (Reading database ... 122403 files and directories currently installed.)
# Preparing to unpack .../00-logrotate_3.19.0-1ubuntu1.1_amd64.deb ...
# Unpacking logrotate (3.19.0-1ubuntu1.1) ...
# Selecting previously unselected package netbase.
# Preparing to unpack .../01-netbase_6.3_all.deb ...
# Unpacking netbase (6.3) ...
# Selecting previously unselected package libboost-serialization1.74.0:amd64.
# Preparing to unpack .../02-libboost-serialization1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-serialization1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libcommon-sense-perl:amd64.
# Preparing to unpack .../03-libcommon-sense-perl_3.75-2build1_amd64.deb ...
# Unpacking libcommon-sense-perl:amd64 (3.75-2build1) ...
# Selecting previously unselected package libgmpxx4ldbl:amd64.
# Preparing to unpack .../04-libgmpxx4ldbl_2%3a6.2.1+dfsg-3ubuntu1_amd64.deb ...
# Unpacking libgmpxx4ldbl:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# Selecting previously unselected package libjson-perl.
# Preparing to unpack .../05-libjson-perl_4.04000-1_all.deb ...
# Unpacking libjson-perl (4.04000-1) ...
# Selecting previously unselected package libtypes-serialiser-perl.
# Preparing to unpack .../06-libtypes-serialiser-perl_1.01-1_all.deb ...
# Unpacking libtypes-serialiser-perl (1.01-1) ...
# Selecting previously unselected package libjson-xs-perl.
# Preparing to unpack .../07-libjson-xs-perl_4.040-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libjson-xs-perl (4.040-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libllvm14:amd64.
# Preparing to unpack .../08-libllvm14_1%3a14.0.0-1ubuntu1.1_amd64.deb ...
# Unpacking libllvm14:amd64 (1:14.0.0-1ubuntu1.1) ...
# Selecting previously unselected package libprotobuf-c1:amd64.
# Preparing to unpack .../09-libprotobuf-c1_1.3.3-1ubuntu2.1_amd64.deb ...
# Unpacking libprotobuf-c1:amd64 (1.3.3-1ubuntu2.1) ...
# Selecting previously unselected package libsfcgal1.
# Preparing to unpack .../10-libsfcgal1_1.4.1-1_amd64.deb ...
# Unpacking libsfcgal1 (1.4.1-1) ...
# Selecting previously unselected package postgis.
# Preparing to unpack .../11-postgis_3.4.1+dfsg-1~jammy0_amd64.deb ...
# Unpacking postgis (3.4.1+dfsg-1~jammy0) ...
# Selecting previously unselected package postgis-doc.
# Preparing to unpack .../12-postgis-doc_3.4.1+dfsg-1~jammy0_all.deb ...
# Unpacking postgis-doc (3.4.1+dfsg-1~jammy0) ...
# Selecting previously unselected package postgresql-client-common.
# Preparing to unpack .../13-postgresql-client-common_238_all.deb ...
# Unpacking postgresql-client-common (238) ...
# Selecting previously unselected package postgresql-client-14.
# Preparing to unpack .../14-postgresql-client-14_14.23-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking postgresql-client-14 (14.23-0ubuntu0.22.04.1) ...
# Selecting previously unselected package ssl-cert.
# Preparing to unpack .../15-ssl-cert_1.1.2_all.deb ...
# Unpacking ssl-cert (1.1.2) ...
# Selecting previously unselected package postgresql-common.
# Preparing to unpack .../16-postgresql-common_238_all.deb ...
# Adding 'diversion of /usr/bin/pg_config to /usr/bin/pg_config.libpq-dev by postgresql-common'
# Unpacking postgresql-common (238) ...
# Selecting previously unselected package postgresql-14.
# Preparing to unpack .../17-postgresql-14_14.23-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking postgresql-14 (14.23-0ubuntu0.22.04.1) ...
# Selecting previously unselected package postgresql.
# Preparing to unpack .../18-postgresql_14+238_all.deb ...
# Unpacking postgresql (14+238) ...
# Selecting previously unselected package postgresql-14-postgis-3-scripts.
# Preparing to unpack .../19-postgresql-14-postgis-3-scripts_3.4.1+dfsg-1~jammy0_all.deb ...
# Unpacking postgresql-14-postgis-3-scripts (3.4.1+dfsg-1~jammy0) ...
# Selecting previously unselected package postgresql-14-postgis-3.
# Preparing to unpack .../20-postgresql-14-postgis-3_3.4.1+dfsg-1~jammy0_amd64.deb ...
# Unpacking postgresql-14-postgis-3 (3.4.1+dfsg-1~jammy0) ...
# Selecting previously unselected package postgresql-contrib.
# Preparing to unpack .../21-postgresql-contrib_14+238_all.deb ...
# Unpacking postgresql-contrib (14+238) ...
# Selecting previously unselected package postgresql-postgis-scripts.
# Preparing to unpack .../22-postgresql-postgis-scripts_3.4.1+dfsg-1~jammy0_all.deb ...
# Unpacking postgresql-postgis-scripts (3.4.1+dfsg-1~jammy0) ...
# Selecting previously unselected package postgresql-postgis.
# Preparing to unpack .../23-postgresql-postgis_3.4.1+dfsg-1~jammy0_amd64.deb ...
# Unpacking postgresql-postgis (3.4.1+dfsg-1~jammy0) ...
# Selecting previously unselected package sysstat.
# Preparing to unpack .../24-sysstat_12.5.2-2ubuntu0.2_amd64.deb ...
# Unpacking sysstat (12.5.2-2ubuntu0.2) ...
# Setting up logrotate (3.19.0-1ubuntu1.1) ...
# Created symlink /etc/systemd/system/timers.target.wants/logrotate.timer → /lib/systemd/system/logrotate.timer.
# Setting up libcommon-sense-perl:amd64 (3.75-2build1) ...
# Setting up postgis (3.4.1+dfsg-1~jammy0) ...
# Setting up postgresql-14-postgis-3-scripts (3.4.1+dfsg-1~jammy0) ...
# update-alternatives: using /usr/share/postgresql/14/extension/postgis-3.control to provide /usr/share/postgresql/14/extension/postgis.control (postgresql-14-postgis.control) in auto mode
# Setting up libprotobuf-c1:amd64 (1.3.3-1ubuntu2.1) ...
# Setting up postgis-doc (3.4.1+dfsg-1~jammy0) ...
# Setting up libgmpxx4ldbl:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# Setting up ssl-cert (1.1.2) ...
# Setting up libboost-serialization1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libllvm14:amd64 (1:14.0.0-1ubuntu1.1) ...
# Setting up libtypes-serialiser-perl (1.01-1) ...
# Setting up libjson-perl (4.04000-1) ...
# Setting up netbase (6.3) ...
# Setting up postgresql-postgis-scripts (3.4.1+dfsg-1~jammy0) ...
# Setting up libsfcgal1 (1.4.1-1) ...
# Setting up sysstat (12.5.2-2ubuntu0.2) ...
#
# Creating config file /etc/default/sysstat with new version
# update-alternatives: using /usr/bin/sar.sysstat to provide /usr/bin/sar (sar) in auto mode
# Created symlink /etc/systemd/system/sysstat.service.wants/sysstat-collect.timer → /lib/systemd/system/sysstat-collect.timer.
# Created symlink /etc/systemd/system/sysstat.service.wants/sysstat-summary.timer → /lib/systemd/system/sysstat-summary.timer.
# Created symlink /etc/systemd/system/multi-user.target.wants/sysstat.service → /lib/systemd/system/sysstat.service.
# Setting up postgresql-client-common (238) ...
# Setting up libjson-xs-perl (4.040-0ubuntu0.22.04.1) ...
# Setting up postgresql-client-14 (14.23-0ubuntu0.22.04.1) ...
# update-alternatives: using /usr/share/postgresql/14/man/man1/psql.1.gz to provide /usr/share/man/man1/psql.1.gz (psql.1.gz) in auto mode
# Setting up postgresql-common (238) ...
# Adding user postgres to group ssl-cert
#
# Creating config file /etc/postgresql-common/createcluster.conf with new version
# Building PostgreSQL dictionaries from installed myspell/hunspell packages...
# Removing obsolete dictionary files:
# Created symlink /etc/systemd/system/multi-user.target.wants/postgresql.service → /lib/systemd/system/postgresql.service.
# Setting up postgresql-14 (14.23-0ubuntu0.22.04.1) ...
# Creating new PostgreSQL cluster 14/main ...
# /usr/lib/postgresql/14/bin/initdb -D /var/lib/postgresql/14/main --auth-local peer --auth-host scram-sha-256 --no-instructions
# The files belonging to this database system will be owned by user "postgres".
# This user must also own the server process.
#
# The database cluster will be initialized with locale "en_US.UTF-8".
# The default database encoding has accordingly been set to "UTF8".
# The default text search configuration will be set to "english".
#
# Data page checksums are disabled.
#
# fixing permissions on existing directory /var/lib/postgresql/14/main ... ok
# creating subdirectories ... ok
# selecting dynamic shared memory implementation ... posix
# selecting default max_connections ... 100
# selecting default shared_buffers ... 128MB
# selecting default time zone ... Etc/UTC
# creating configuration files ... ok
# running bootstrap script ... ok
# performing post-bootstrap initialization ... ok
# syncing data to disk ... ok
# update-alternatives: using /usr/share/postgresql/14/man/man1/postmaster.1.gz to provide /usr/share/man/man1/postmaster.1.gz (postmaster.1.gz) in auto mode
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up postgresql-14-postgis-3 (3.4.1+dfsg-1~jammy0) ...
# Setting up postgresql-contrib (14+238) ...
# Setting up postgresql (14+238) ...
# Setting up postgresql-postgis (3.4.1+dfsg-1~jammy0) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
#  * Starting PostgreSQL 14 database server
#    ...done.
# ALTER ROLE
# CREATE EXTENSION

# %%
import osmnx as ox
import geopandas as gpd
from sqlalchemy import create_engine, text

ENGINE = create_engine("postgresql+psycopg2://postgres:postgres@localhost:5432/pilani_db", pool_pre_ping=True)

tags = {
    'amenity': True, 'building': True, 'leisure': True,
    'shop': True, 'sport': True, 'office': True,
    'tourism': True, 'historic': True, 'highway': ['bus_stop'],
    'man_made': True, 'natural': True, 'healthcare': True,
    'wheelchair': True, 'opening_hours': True, 'cuisine': True,
    'diet:vegan': True, 'takeaway': True, 'internet_access': True, 'dog': True
}

# IIT Bombay coordinates with 3km radius
lat, lon = ox.geocode("IIT Bombay, Mumbai")
print(f"📍 IIT Bombay located at: ({lat}, {lon})")

gdf = ox.features_from_point((lat, lon), tags=tags, dist=3000).reset_index()

keep_cols = [c for c in gdf.columns if c != 'geometry'] + ['geometry']
gdf = gdf[keep_cols]

for col in gdf.select_dtypes(include=['object', 'category']).columns:
    if col != 'geometry':
        gdf[col] = gdf[col].astype(object).where(gdf[col].notna(), None)

if gdf.crs is None:
    gdf = gdf.set_crs(epsg=4326)
else:
    gdf = gdf.to_crs(epsg=4326)

with ENGINE.connect() as conn:
    conn.execute(text("CREATE EXTENSION IF NOT EXISTS postgis;"))
    conn.commit()

gdf.to_postgis("campus_places", ENGINE, if_exists='replace', index=False)
print(f"✅ Loaded {len(gdf)} features for IIT Bombay!")
# Out:
# 📍 IIT Bombay located at: (19.1326186, 72.9149702)
# ✅ Loaded 5325 features for IIT Bombay!

# %%
import pandas as pd
from sqlalchemy import text

print("🔍 Discovering what data exists in the IIT Bombay database...\n")

# --- Discover amenity values that have named places ---
with ENGINE.connect() as conn:
    amenities = conn.execute(text("""
        SELECT amenity, COUNT(*) as cnt
        FROM campus_places
        WHERE name IS NOT NULL AND name != 'nan' AND amenity IS NOT NULL
        GROUP BY amenity ORDER BY cnt DESC
    """)).fetchall()

    shops = conn.execute(text("""
        SELECT shop, COUNT(*) as cnt
        FROM campus_places
        WHERE name IS NOT NULL AND name != 'nan' AND shop IS NOT NULL
        GROUP BY shop ORDER BY cnt DESC
    """)).fetchall()

    leisure = conn.execute(text("""
        SELECT leisure, COUNT(*) as cnt
        FROM campus_places
        WHERE name IS NOT NULL AND name != 'nan' AND leisure IS NOT NULL
        GROUP BY leisure ORDER BY cnt DESC
    """)).fetchall()

    sports = conn.execute(text("""
        SELECT sport, COUNT(*) as cnt
        FROM campus_places
        WHERE name IS NOT NULL AND name != 'nan' AND sport IS NOT NULL
        GROUP BY sport ORDER BY cnt DESC
    """)).fetchall()

    buildings = conn.execute(text("""
        SELECT building, COUNT(*) as cnt
        FROM campus_places
        WHERE name IS NOT NULL AND name != 'nan' AND building IS NOT NULL
        GROUP BY building ORDER BY cnt DESC
    """)).fetchall()

    tourism_vals = conn.execute(text("""
        SELECT tourism, COUNT(*) as cnt
        FROM campus_places
        WHERE name IS NOT NULL AND name != 'nan' AND tourism IS NOT NULL
        GROUP BY tourism ORDER BY cnt DESC
    """)).fetchall()

    historic_vals = conn.execute(text("""
        SELECT historic, COUNT(*) as cnt
        FROM campus_places
        WHERE name IS NOT NULL AND name != 'nan' AND historic IS NOT NULL
        GROUP BY historic ORDER BY cnt DESC
    """)).fetchall()

    # Check advanced boolean tags
    wheelchair_count = conn.execute(text("""
        SELECT COUNT(*) FROM campus_places
        WHERE name IS NOT NULL AND name != 'nan' AND wheelchair = 'yes'
    """)).scalar()

    vegan_count = conn.execute(text("""
        SELECT COUNT(*) FROM campus_places
        WHERE name IS NOT NULL AND name != 'nan' AND "diet:vegan" = 'yes'
    """)).scalar()

    wifi_count = conn.execute(text("""
        SELECT COUNT(*) FROM campus_places
        WHERE name IS NOT NULL AND name != 'nan' AND internet_access IS NOT NULL
    """)).scalar()

    total_named = conn.execute(text("""
        SELECT COUNT(*) FROM campus_places WHERE name IS NOT NULL AND name != 'nan'
    """)).scalar()

print(f"📊 Total named places: {total_named}\n")
print("🍕 AMENITIES with named places:")
for a, c in amenities: print(f"   {a}: {c}")
print(f"\n🏪 SHOPS with named places:")
for s, c in shops: print(f"   {s}: {c}")
print(f"\n🌳 LEISURE with named places:")
for l, c in leisure: print(f"   {l}: {c}")
print(f"\n🏏 SPORTS with named places:")
for s, c in sports: print(f"   {s}: {c}")
print(f"\n🏢 BUILDINGS with named places:")
for b, c in buildings: print(f"   {b}: {c}")
print(f"\n🏛️ TOURISM with named places:")
for t, c in tourism_vals: print(f"   {t}: {c}")
print(f"\n📜 HISTORIC with named places:")
for h, c in historic_vals: print(f"   {h}: {c}")
print(f"\n♿ Wheelchair accessible: {wheelchair_count}")
print(f"🥬 Vegan tagged: {vegan_count}")
print(f"📶 WiFi tagged: {wifi_count}")
# Out:
# 🔍 Discovering what data exists in the IIT Bombay database...
#
# 📊 Total named places: 1610
#
# 🍕 AMENITIES with named places:
#    waste_basket: 105
#    hospital: 49
#    toilets: 46
#    restaurant: 41
#    bench: 39
#    student_accommodation: 33
#    college: 31
#    place_of_worship: 27
#    fast_food: 26
#    drinking_water: 25
#    school: 24
#    bank: 20
#    cafe: 19
#    clinic: 17
#    library: 15
#    electronics: 8
#    taxi: 8
#    bus_station: 7
#    bar: 7
#    fuel: 7
#    pharmacy: 6
#    jeweller: 4
#    parking: 4
#    pub: 3
#    post_office: 3
#    police: 3
#    dentist: 3
#    community_centre: 3
#    prep_school: 3
#    ice_cream: 3
#    theatre: 2
#    electronics_repair: 2
#    studio: 2
#    events_venue: 2
#    bicycle_repair_station: 2
#    public_building: 2
#    atm: 2
#    marketplace: 2
#    bicycle_parking: 2
#    university: 1
#    phone service provider: 1
#    blood_bank: 1
#    fast_food;cafe: 1
#    water_point: 1
#    events_space: 1
#    doctors: 1
#    beauty: 1
#    dojo: 1
#    clothes: 1
#    parking_space: 1
#    canteen: 1
#    boat_rental: 1
#    mess: 1
#
# 🏪 SHOPS with named places:
#    copyshop: 21
#    hairdresser: 20
#    beauty: 16
#    clothes: 14
#    tea: 13
#    tailor: 12
#    supermarket: 10
#    convenience: 9
#    mall: 7
#    optician: 7
#    confectionery: 5
#    mobile_phone: 4
#    stationery: 3
#    chemist: 3
#    computer: 3
#    ticket: 2
#    laundry: 2
#    department_store: 2
#    yes: 2
#    photo: 2
#    shoes: 2
#    pastry: 2
#    jewelry: 2
#    medical_supply: 2
#    travel_agency: 2
#    books: 2
#    bicycle: 1
#    tiles: 1
#    party: 1
#    nutrition_supplements: 1
#    greengrocer: 1
#    tobacco: 1
#    gas: 1
#    bakery: 1
#    sports: 1
#    photo_studio: 1
#    watches: 1
#    bag: 1
#    car_repair: 1
#    motorcycle_repair: 1
#    general: 1
#    musical_instrument: 1
#    furniture: 1
#    cosmetics: 1
#    dairy: 1
#    gift: 1
#    frame: 1
#    hardware: 1
#
# 🌳 LEISURE with named places:
#    park: 27
#    pitch: 14
#    playground: 9
#    garden: 8
#    sports_centre: 4
#    fitness_centre: 3
#    swimming_pool: 2
#    track: 2
#    bandstand: 2
#    adult_gaming_centre: 1
#    nature_reserve: 1
#    sports_hall: 1
#    dog_park: 1
#
# 🏏 SPORTS with named places:
#    cricket: 3
#    basketball: 2
#    tennis: 2
#    badminton: 2
#    swimming: 2
#    soccer: 2
#    field_hockey: 1
#    yoga: 1
#    table_tennis;table_soccer;pool;chess: 1
#    running: 1
#    soccer;tennis;gym;skates;swimming: 1
#
# 🏢 BUILDINGS with named places:
#    apartments: 262
#    yes: 153
#    university: 58
#    dormitory: 36
#    bungalow: 21
#    residential: 19
#    office: 12
#    school: 12
#    house: 8
#    commercial: 8
#    service: 4
#    church: 4
#    industrial: 4
#    hotel: 3
#    retail: 2
#    mosque: 2
#    college: 2
#    construction: 2
#    Chemtex_House: 1
#    detached: 1
#    civic: 1
#    garage: 1
#    public: 1
#    hospital: 1
#    greenhouse: 1
#    train_station: 1
#    shop: 1
#
# 🏛️ TOURISM with named places:
#    artwork: 11
#    hotel: 11
#    hostel: 9
#    attraction: 4
#    viewpoint: 2
#    guest_house: 2
#
# 📜 HISTORIC with named places:
#    monument: 3
#
# ♿ Wheelchair accessible: 8
# 🥬 Vegan tagged: 2
# 📶 WiFi tagged: 17

# %%
"""
=============================================================================
BITS Pilani SQL Evaluation Framework  —  v4.1 (F1-Score Semantics)
=============================================================================
Key fixes:
  • Semantic evaluation now uses F1-Scoring (Precision/Recall).
    A query passes semantic checks if its F1 Score >= 0.75, allowing for
    moderate data variations without failing the whole test.
  • Result sets are automatically stripped and lowercased to prevent
    hidden whitespace or casing mismatches.
=============================================================================
"""

import os
import re
import warnings
import torch
import pandas as pd
import openpyxl
from contextlib import redirect_stdout
from tabulate import tabulate
from sqlalchemy import create_engine, text
from sqlglot import parse_one
from sqlglot import expressions as exp
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

warnings.filterwarnings("ignore")
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# ─────────────────────────────────────────────────────────────────────────────
# 1. CONFIG
# ─────────────────────────────────────────────────────────────────────────────
DB_URL     = "postgresql://postgres:postgres@localhost:5432/pilani_db"
#MODEL_NAME = "Qwen/Qwen2.5-Coder-7B-Instruct"
#MODEL_NAME = "defog/llama-3-sqlcoder-8b"
#MODEL_NAME = "deepseek-ai/deepseek-coder-7b-instruct-v1.5"
MODEL_NAME = "seeklhy/codes-7b"

ENGINE = create_engine(
    DB_URL.replace("postgresql://", "postgresql+psycopg2://"),
    pool_pre_ping=True, pool_size=5, max_overflow=2
)

# ─────────────────────────────────────────────────────────────────────────────
# 2. LOAD MODEL
# ─────────────────────────────────────────────────────────────────────────────
print(f"🚀 Loading {MODEL_NAME}...")
HF_TOKEN = os.getenv("HF_TOKEN")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, token=HF_TOKEN)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True, bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16, bnb_4bit_use_double_quant=True,
)
sql_model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME, device_map="auto", quantization_config=bnb_config,
    dtype=torch.bfloat16, low_cpu_mem_usage=True, token=HF_TOKEN
)
sql_model.generation_config.temperature = None
sql_model.generation_config.top_p = None
print("✅ Model ready!\n")

# --- 3. DYNAMIC PROMPT TEMPLATE (Model-Agnostic) ---
PROMPT_TEMPLATE = """You are an expert PostgreSQL + PostGIS developer.
Generate a VALID PostGIS SQL query for the user's question.

The database uses OpenStreetMap-style tagging with a single denormalized table.

====================================================================
DATABASE SCHEMA: Table → campus_places
====================================================================

CORE COLUMNS:
- element, id, name, short_name, official_name, alt_name, name:en, name:hi
- geometry (PostGIS geometry column)

CATEGORY TAG COLUMNS (each stores text values):
- amenity: restaurant, blood_bank, cafe, club, clinic, research_institute, hospital, conference_centre, ice_cream, fuel, fast_food, college, dentist, school, place_of_worship, library, post_office, courthouse, food_court, pharmacy, university, atm, bank
- building: university=department, dormitory, apartments, residential, yes, hospital, university
- office: yes, government, advertising_agency
- shop: hairdresser, supermarket, department_store, convenience, bakery
- healthcare: hospital, pharmacy
- tourism: artwork, gallery, museum, hotel, viewpoint, hostel
- leisure: nature_reserve, pitch, park, garden, sports_centre, swimming_pool, playground
- sport: badminton, cricket, table_tennis, multi, volleyball, skateboard
- historic: manor, aircraft, memorial
- religion: hindu
- education: school
- man_made: silo
- artwork_type: statue
- wheelchair, opening_hours, cuisine, "diet:vegan", takeaway, internet_access, dog

====================================================================
INTENT MAPPING
====================================================================
Map the user's emotional or contextual intent to the correct tags:

- Quiet/Relaxing → amenity ILIKE '%library%' OR leisure ILIKE '%park%'
- Lively/Energetic → amenity ILIKE '%bar%' OR amenity ILIKE '%pub%'
- Aesthetic/Tourism → tourism IS NOT NULL OR historic IS NOT NULL
- Family/Kid-Friendly → leisure ILIKE '%playground%'
- Pet-Friendly → "dog" = 'yes' OR leisure ILIKE '%park%'
- Group/Gathering → amenity ILIKE '%food_court%' OR amenity ILIKE '%restaurant%'
- Fast/Quick → amenity ILIKE '%fast_food%' OR "takeaway" = 'yes'
- Accessible → "wheelchair" = 'yes'
- Budget/Cheap → amenity ILIKE '%canteen%' OR amenity ILIKE '%food_court%'
- Productivity/Study → "internet_access" = 'wlan' OR amenity ILIKE '%library%'
- Utility/Errand → amenity ILIKE '%atm%' OR amenity ILIKE '%bank%'
- Dietary (Vegan) → "diet:vegan" = 'yes'
- Late Night → "opening_hours" ILIKE '%24/7%'

====================================================================
SQL CONVENTIONS
====================================================================
1. Always filter: WHERE name IS NOT NULL AND name != 'nan'
2. Use ILIKE '%term%' for text matching.
3. Columns containing ":" must be double-quoted (e.g., "diet:vegan").
4. ORDER BY name ASC
5. LIMIT 5
6. Output ONLY valid PostgreSQL SQL. No explanation.

====================================================================
SPATIAL QUERIES
====================================================================
For distance-based queries, cast geometries to geography for meter-based measurements:
- Within X meters: ST_DWithin(a.geometry::geography, b.geometry::geography, X)
- Nearest/closest: ORDER BY ST_Distance(a.geometry::geography, b.geometry::geography) ASC

====================================================================
EXAMPLES
====================================================================

User: "Find cafes or restaurants."
SQL:
SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE '%cafe%' OR amenity ILIKE '%restaurant%') ORDER BY name ASC LIMIT 5;

User: "Find a cafe within 500 meters of the library"
SQL:
SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name
FROM campus_places target
JOIN campus_places ref ON ST_DWithin(target.geometry::geography, ref.geometry::geography, 500)
WHERE target.name IS NOT NULL AND target.name != 'nan'
  AND target.amenity ILIKE '%cafe%'
  AND ref.amenity ILIKE '%library%'
ORDER BY target.name ASC LIMIT 5;

User: "Where is the closest ATM to the boys hostel?"
SQL:
SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name
FROM campus_places target
JOIN campus_places ref ON 1=1
WHERE target.name IS NOT NULL AND target.name != 'nan'
  AND target.amenity ILIKE '%atm%'
  AND (ref.name ILIKE '%hostel%' OR ref.building ILIKE '%dormitory%')
ORDER BY ST_Distance(target.geometry::geography, ref.geometry::geography) ASC
LIMIT 1;
"""




# ─────────────────────────────────────────────────────────────────────────────
# 4. SQL GENERATION (Model Agnostic Updates)
# ─────────────────────────────────────────────────────────────────────────────
def clean_sql(raw: str) -> str | None:
    """A resilient cleaner for Qwen, DeepSeek, and other general LLMs."""
    if not raw:
        return None

    # 1. NEW: Fix DeepSeek Byte-Level Tokenizer Artifacts (Converts them back to real spaces/newlines)
    raw = raw.replace("Ġ", " ").replace("Ċ", "\n").replace("č", "\r")

    raw = raw.strip()

    # 2. Try to find a markdown block first (e.g. ```sql ... ```)
    match = re.search(r"```(?:sql)?\s*(.*?)```", raw, re.DOTALL | re.IGNORECASE)
    if match:
        return match.group(1).strip()

    # 3. Fallback: Extract from the first SELECT to the first semicolon (or end of string)
    match = re.search(r"(SELECT\s+.*?(?:;|$))", raw, re.DOTALL | re.IGNORECASE)
    if match:
        return match.group(1).strip()

    # 4. Absolute fallback: just return the raw string
    return raw


def get_sql(question: str) -> str | None:
    # Use standard ChatML format to be model-agnostic
    messages = [
        {"role": "system", "content": PROMPT_TEMPLATE},
        {"role": "user", "content": f"Junior says: \"{question}\"\n\nSQL Query:"}
    ]

    # Automatically apply the correct chat template for Qwen
    prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    input_length = inputs.input_ids.shape[1]

    with torch.no_grad():
        outputs = sql_model.generate(
            **inputs,
            max_new_tokens=300,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id,
            repetition_penalty=1.1,
        )
    torch.cuda.empty_cache()

    new_tokens = outputs[0][input_length:]
    decoded = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()
    return clean_sql(decoded)


def repair_pred_sql(sql: str | None, question: str) -> str | None:
    if not sql:
        return sql

    fixed = sql.strip()

    fixed = re.sub(r"\bdiet_non_vegetarian\b", '"diet:non-vegetarian"', fixed, flags=re.IGNORECASE)
    fixed = re.sub(r"\blit\s*=\s*TRUE\b", "lit ILIKE '%yes%'", fixed, flags=re.IGNORECASE)
    fixed = re.sub(
        r"\b[a-zA-Z]\.place_of_worship\s+IS\s+FALSE\b|\bplace_of_worship\s+IS\s+FALSE\b",
        "(amenity IS NULL OR amenity NOT ILIKE '%place_of_worship%')",
        fixed, flags=re.IGNORECASE
    )

    where_parts = re.split(r"\bWHERE\b", fixed, flags=re.IGNORECASE)
    if len(where_parts) > 2:
        fixed = where_parts[0] + " WHERE " + where_parts[1]
        for part in where_parts[2:]:
            fixed += " AND (" + part.strip() + ")"

    q = question.lower()
    if "bakery" in q:
        fixed = re.sub(r"\bamenity\s+ILIKE\s+'%bakery%'", "shop ILIKE '%bakery%'", fixed, flags=re.IGNORECASE)
    if "swimming pool" in q:
        fixed = re.sub(r"\bamenity\s+ILIKE\s+'%swimming_pool%'", "leisure ILIKE '%swimming_pool%'", fixed, flags=re.IGNORECASE)
    if any(k in q for k in ["badminton", "cricket", "volleyball", "table tennis"]):
        fixed = re.sub(r"\bamenity\s+ILIKE\s+'%(badminton|cricket|volleyball|table_tennis)%'", r"sport ILIKE '%\1%'", fixed, flags=re.IGNORECASE)
    if "dormitor" in q:
        fixed = re.sub(r"\bname\s+ILIKE\s+'%dormitory%'", "building ILIKE '%dormitory%'", fixed, flags=re.IGNORECASE)

    if not re.search(r"name\s+IS\s+NOT\s+NULL", fixed, flags=re.IGNORECASE):
        if re.search(r"\bWHERE\b", fixed, flags=re.IGNORECASE):
            fixed = re.sub(
                r"\bWHERE\b",
                "WHERE name IS NOT NULL AND name != 'nan' AND ",
                fixed, count=1, flags=re.IGNORECASE
            )
        else:
            fixed = fixed.rstrip('; ') + " WHERE name IS NOT NULL AND name != 'nan'"

    if not re.search(r"\bORDER\s+BY\b", fixed, flags=re.IGNORECASE):
        fixed = fixed.rstrip('; ') + " ORDER BY name ASC"
    if not re.search(r"\bLIMIT\s+\d+", fixed, flags=re.IGNORECASE):
        fixed = fixed.rstrip('; ') + " LIMIT 5"

    fixed = re.sub(r"\s+", " ", fixed).strip()
    return fixed.rstrip(';') + ';'

# ─────────────────────────────────────────────────────────────────────────────
# 5. SQL NORMALIZER
# ─────────────────────────────────────────────────────────────────────────────
def normalize_sql(sql: str) -> str:
    if not sql:
        return ""
    sql = re.sub(r";\s*(ORDER\s+BY|LIMIT)", r" \1", sql, flags=re.IGNORECASE)
    sql = re.sub(r'\b[a-zA-Z]\."', '"', sql)
    sql = re.sub(r'\b[a-zA-Z]\.([a-zA-Z_][a-zA-Z0-9_]*)', r'\1', sql)
    sql = re.sub(r'(campus_places)\s+[a-zA-Z]\b', r'\1', sql, flags=re.IGNORECASE)
    sql = re.sub(r'\s+', ' ', sql).strip()
    return sql.lower()

# ─────────────────────────────────────────────────────────────────────────────
# 6. TEST SUITE (unchanged)
# ─────────────────────────────────────────────────────────────────────────────
TEST_SUITE = pd.read_csv('sql_benchmark_v3.csv').to_dict('records')
print(f"✅ Successfully loaded {len(TEST_SUITE)} complex test queries!")

# ─────────────────────────────────────────────────────────────────────────────
# 7. STRUCTURAL EVALUATION
# ─────────────────────────────────────────────────────────────────────────────
def extract_components(sql: str) -> dict:
    try:
        tree = parse_one(sql, dialect="postgres")
    except Exception as e:
        return {"error": str(e)}

    c = {
        "select_cols": set(), "from_tables": set(),
        "where_cols":  set(), "where_ops":   set(),
        "order_cols":  set(), "limit":       None,
    }
    for col   in tree.find_all(exp.Column): c["select_cols"].add(col.name.lower())
    for table in tree.find_all(exp.Table):  c["from_tables"].add(table.name.lower())

    where = tree.find(exp.Where)
    if where:
        for col in where.find_all(exp.Column): c["where_cols"].add(col.name.lower())
        if where.find(exp.ILike): c["where_ops"].add("ilike")
        if where.find(exp.EQ):    c["where_ops"].add("eq")
        if where.find(exp.Is):    c["where_ops"].add("is_null")

    order = tree.find(exp.Order)
    if order:
        for col in order.find_all(exp.Column): c["order_cols"].add(col.name.lower())

    limit = tree.find(exp.Limit)
    if limit: c["limit"] = str(limit.expression)
    return c

def structural_score(gold_sql: str, pred_sql: str) -> dict:
    gold = extract_components(normalize_sql(gold_sql))
    pred = extract_components(normalize_sql(pred_sql))

    if "error" in gold or "error" in pred:
        return {
            "parse_error": True,
            "select_match": False, "from_match": False,
            "where_cols_match": False, "where_ops_match": False,
            "order_match": False, "limit_match": False,
            "structural_score": 0.0,
        }

    checks = {
        "select_match":     gold["select_cols"] == pred["select_cols"],
        "from_match":       gold["from_tables"] == pred["from_tables"],
        "where_cols_match": gold["where_cols"]  == pred["where_cols"],
        "where_ops_match":  gold["where_ops"]   == pred["where_ops"],
        "order_match":      gold["order_cols"]  == pred["order_cols"],
        "limit_match":      gold["limit"]       == pred["limit"],
    }
    return {
        "parse_error": False, **checks,
        "structural_score": round(sum(checks.values()) / len(checks), 3),
    }

# ─────────────────────────────────────────────────────────────────────────────
# 8. SEMANTIC EVALUATION (F1 SCORE UPDATED)
# ─────────────────────────────────────────────────────────────────────────────
def run_query_names(sql: str) -> list | None:
    """Execute SQL and return sorted, normalized list of first-column (name) values."""
    clean = re.sub(r";\s*(ORDER\s+BY|LIMIT)", r" \1", sql, flags=re.IGNORECASE).strip()
    clean = re.sub(r"\bLIMIT\s+\d+", "", clean, flags=re.IGNORECASE).strip()

    if not clean.endswith(";"):
        clean += ";"

    try:
        with ENGINE.connect() as conn:
            result = conn.execute(text(clean))
            rows = result.fetchall()
            # NEW: Strip whitespace and lowercase to prevent false mismatches
            return sorted([str(row[0]).strip().lower() for row in rows if row[0] is not None])
    except Exception as e:
        print(f"    ⚠️  DB exec error: {e}\n    [SQL: {clean[:150]}]")
        return None

def semantic_score(gold_sql: str, pred_sql: str) -> dict:
    gold_names = run_query_names(gold_sql)
    pred_names = run_query_names(pred_sql)

    if gold_names is None or pred_names is None:
        return {"exec_error": True, "semantic_match": False, "f1_score": 0.0,
                "gold_row_count": 0, "pred_row_count": 0}

    # CALCULATE F1 SCORE
    gold_set = set(gold_names)
    pred_set = set(pred_names)

    if not gold_set and not pred_set:
        f1 = 1.0 # Both correctly found 0 rows
    elif not gold_set or not pred_set:
        f1 = 0.0 # One found rows, the other found none
    else:
        intersection = gold_set.intersection(pred_set)
        precision = len(intersection) / len(pred_set)
        recall = len(intersection) / len(gold_set)
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

    # THRESHOLD: 50% overlap is considered a semantic match
    is_match = f1 >= 0.5

    return {
        "exec_error": False,
        "semantic_match": is_match,
        "f1_score": f1,
        "gold_row_count": len(gold_names),
        "pred_row_count": len(pred_names),
        "missing_names":  sorted(gold_set - pred_set),
        "extra_names":    sorted(pred_set - gold_set),
    }

# ─────────────────────────────────────────────────────────────────────────────
# 9. HYBRID EVALUATOR
# ─────────────────────────────────────────────────────────────────────────────
def hybrid_eval(gold_sql: str, pred_sql: str) -> dict:
    struct = structural_score(gold_sql, pred_sql)
    sem    = semantic_score(gold_sql, pred_sql)
    s      = struct["structural_score"]
    m      = sem["semantic_match"]

    if   s >= 0.50 and m: verdict = "✅ PASS"
    elif s >= 0.50:       verdict = "⚠️  STRUCT_ONLY"
    elif m:               verdict = "⚠️  SEM_ONLY"
    else:                 verdict = "❌ FAIL"

    return {**struct, **sem, "verdict": verdict, "hybrid_pass": verdict == "✅ PASS"}

# ─────────────────────────────────────────────────────────────────────────────
# 10. TEST RUNNER
# ─────────────────────────────────────────────────────────────────────────────
def run_tests() -> pd.DataFrame:
    rows  = []
    total = len(TEST_SUITE)

    for i, test in enumerate(TEST_SUITE):
        tid = test["id"]
        print(f"[{i+1:02d}/{total}] {test['difficulty'].upper():6s} | "
              f"{test['cluster']:12s} | {test['question'][:55]}")

        raw_pred_sql = get_sql(test["question"])
        pred_sql = repair_pred_sql(raw_pred_sql, test["question"])
        print(f"        💻 Pred: {(pred_sql or '(none)')[:100]}")

        if not pred_sql:
            print("        → ⚠️  Model returned no SQL\n")
            rows.append({
                "id": tid, "cluster": test["cluster"],
                "difficulty": test["difficulty"], "question": test["question"],
                "verdict": "⚠️  NO_PRED", "hybrid_pass": False,
                "structural_score": 0.0, "semantic_match": False, "f1_score": 0.0,
                "select_match": False, "from_match": False,
                "where_cols_match": False, "where_ops_match": False,
                "order_match": False, "limit_match": False,
                "gold_row_count": 0, "pred_row_count": 0,
                "missing_names": [], "extra_names": [],
                "gold_sql": test["gold_sql"].strip(), "pred_sql": "",
                "raw_pred_sql": "",
            })
            continue

        result = hybrid_eval(test["gold_sql"], pred_sql)

        missing = result.get("missing_names", [])
        extra   = result.get("extra_names", [])

        print(f"        → {result['verdict']}  "
              f"(struct={result['structural_score']:.2f}, "
              f"sem_F1={result['f1_score']:.2f}, "
              f"gold={result['gold_row_count']} pred={result['pred_row_count']}"
              + (f", missing={missing[:3]}" if missing else "")
              + (f", extra={extra[:3]}"    if extra   else "")
              + ")\n")

        rows.append({
            "id": tid, "cluster": test["cluster"],
            "difficulty": test["difficulty"], "question": test["question"],
            "verdict": result["verdict"], "hybrid_pass": result["hybrid_pass"],
            "structural_score": result["structural_score"],
            "semantic_match":   result["semantic_match"],
            "f1_score":         result["f1_score"],
            "select_match":     result.get("select_match", False),
            "from_match":       result.get("from_match", False),
            "where_cols_match": result.get("where_cols_match", False),
            "where_ops_match":  result.get("where_ops_match", False),
            "order_match":      result.get("order_match", False),
            "limit_match":      result.get("limit_match", False),
            "gold_row_count":   result["gold_row_count"],
            "pred_row_count":   result["pred_row_count"],
            "missing_names":    str(missing),
            "extra_names":      str(extra),
            "gold_sql":         test["gold_sql"].strip(),
            "pred_sql":         pred_sql,
            "raw_pred_sql":     raw_pred_sql or "",
        })

    return pd.DataFrame(rows)

# ─────────────────────────────────────────────────────────────────────────────
# 11. REPORT
# ─────────────────────────────────────────────────────────────────────────────
def print_report(df: pd.DataFrame, report_file: str = None):
    # We use a custom print function that prints to both terminal and file if a file is provided
    import sys

    class Tee:
        def __init__(self, *files):
            self.files = files
        def write(self, obj):
            for f in self.files:
                f.write(obj)
                f.flush()
        def flush(self):
            for f in self.files:
                f.flush()

    if report_file:
        f = open(report_file, "w", encoding="utf-8")
        original_stdout = sys.stdout
        sys.stdout = Tee(sys.stdout, f)

    try:
        total       = len(df)
        passed      = df["hybrid_pass"].sum()
        sem_only    = (df["verdict"] == "⚠️  SEM_ONLY").sum()
        struct_only = (df["verdict"] == "⚠️  STRUCT_ONLY").sum()
        failed      = (df["verdict"] == "❌ FAIL").sum()
        no_pred     = (df["verdict"] == "⚠️  NO_PRED").sum()

        print("\n" + "=" * 65)
        print("📊  HYBRID EVALUATION REPORT  v4.1")
        print("=" * 65)
        print(f"  Total          : {total}")
        print(f"  ✅ PASS        : {passed}  ({100*passed/total:.1f}%)")
        print(f"  ❌ FAIL        : {failed}  ({100*failed/total:.1f}%)")
        print(f"  ⚠️  STRUCT_ONLY : {struct_only}")
        print(f"  ⚠️  SEM_ONLY    : {sem_only}")
        print(f"  ⚠️  NO_PRED     : {no_pred}")
        print(f"\n  Avg Struct Score  : {df['structural_score'].mean():.3f}")
        print(f"  Avg F1 Semantic   : {df['f1_score'].mean():.3f}")

        diff_order = ["easy", "medium", "hard", "extra"]
        diff_df = df[df["difficulty"].isin(diff_order)].copy()
        diff_df["difficulty"] = pd.Categorical(
            diff_df["difficulty"], categories=diff_order, ordered=True)

        print("\n── Per-Difficulty (Spider-style) ──────────────────────────")
        ds = diff_df.groupby("difficulty", observed=True).agg(
            total=("id","count"), passed=("hybrid_pass","sum"),
            avg_struct=("structural_score","mean"), avg_f1=("f1_score","mean"),
        ).reset_index()
        ds["pass_%"] = (ds["passed"] / ds["total"] * 100).round(1)
        print(tabulate(ds, headers="keys", tablefmt="rounded_outline", showindex=False))

        failures = df[df["hybrid_pass"] == False]
        if not failures.empty:
            print("\n── Failed / Warning Cases ─────────────────────────────────")
            for _, row in failures.iterrows():
                print(f"\n  [{row['id']:02d}] {row['verdict']}  [{row['difficulty']}]  {row['question']}")
                print(f"       GOLD    : {row['gold_sql'][:110].strip()}")
                print(f"       PRED    : {(row['pred_sql'] or '(none)')[:110].strip()}")
                if row['missing_names'] not in ('[]', ''):
                    print(f"       MISSING : {row['missing_names']}")
                if row['extra_names'] not in ('[]', ''):
                    print(f"       EXTRA   : {row['extra_names']}")

        print("\n" + "=" * 65)
    finally:
        if report_file:
            sys.stdout = original_stdout
            f.close()

# ─────────────────────────────────────────────────────────────────────────────
# 12. EXCEL EXPORT
# ─────────────────────────────────────────────────────────────────────────────
def export_to_excel(df: pd.DataFrame, file_path: str):
    """Export results to Excel with detailed mismatches sheet + concise summary sheet."""
    print("💾 Generating Excel report...")
    with pd.ExcelWriter(file_path, engine="openpyxl") as writer:

        # --- Sheet 1: Summary ---
        summary_cols = ["id", "question", "difficulty", "verdict", "structural_score", "f1_score", "semantic_match"]
        summary_df = df[summary_cols].copy()
        summary_df['semantic_match'] = summary_df['semantic_match'].apply(lambda x: "✓" if x else "✗")
        summary_df.to_excel(writer, sheet_name="Summary", index=False)

        # --- Sheet 2: Mismatches ---
        mismatch_data = []
        for _, row in df[df["hybrid_pass"] == False].iterrows():
            missing = str(row.get("missing_names", "")).replace("['", "").replace("']", "").replace("'", "")
            extra = str(row.get("extra_names", "")).replace("['", "").replace("']", "").replace("'", "")

            mismatch_data.append({
                "id": row["id"],
                "question": row["question"],
                "verdict": row["verdict"],
                "f1_score": row["f1_score"],
                "missing_values": missing if missing != "[]" else "",
                "extra_values": extra if extra != "[]" else "",
                "gold_count": row["gold_row_count"],
                "pred_count": row["pred_row_count"]
            })

        if mismatch_data:
            mismatch_df = pd.DataFrame(mismatch_data)
            mismatch_df.to_excel(writer, sheet_name="Mismatches", index=False)

    print(f"✅ Excel report saved to {file_path}")

# ─────────────────────────────────────────────────────────────────────────────
# 13. ENTRY POINT
# ─────────────────────────────────────────────────────────────────────────────
if __name__ == "__main__":
    print("=" * 65)
    print("🧪  BITS Pilani SQL Eval  —  DeepSeek-Coder-7B")
    print("=" * 65 + "\n")

    results_df = run_tests()

    report_file = "eval_report_deepseek.txt"
    csv_file    = "eval_results_deepseek.csv"
    excel_file  = "eval_results_deepseek.xlsx"

    # 1. Print report (and save to .txt)
    print_report(results_df, report_file)
    print(f"💾 Text report saved to {report_file}")

    # 2. Export CSV
    results_df.to_csv(csv_file, index=False)
    print(f"💾 CSV report saved to {csv_file}")

    # 3. Export Excel
    export_to_excel(results_df, excel_file)
# Out:
# 🚀 Loading deepseek-ai/deepseek-coder-7b-instruct-v1.5...
# Loading weights:   0%|          | 0/273 [00:00<?, ?it/s]
# ✅ Model ready!
#
# ✅ Successfully loaded 50 complex test queries!
# =================================================================
# 🧪  BITS Pilani SQL Eval  —  DeepSeek-Coder-7B
# =================================================================
#
# [01/50] EASY   | Simple       | Where is the library?
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE
#         → ✅ PASS  (struct=1.00, sem_F1=1.00, gold=15 pred=15)
#
# [02/50] EASY   | Simple       | Show me all restaurants.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE
#         → ✅ PASS  (struct=1.00, sem_F1=1.00, gold=41 pred=41)
#
# [03/50] EASY   | Simple       | Where can I get coffee?
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE
#         → ✅ PASS  (struct=1.00, sem_F1=1.00, gold=20 pred=20)
#
# [04/50] EASY   | Simple       | Find the pharmacy.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE
#         → ✅ PASS  (struct=1.00, sem_F1=1.00, gold=6 pred=6)
#
# [05/50] EASY   | Simple       | I need to withdraw cash, find an ATM.
#         💻 Pred: SELECT target.geometry, target.name, target.amenity, ST_Distance(target.geometry::geography, ref.geo
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedTable) relation "campus_placestarget" does not exist
# LINE 1: ...graphy, ref.geometry::geography) AS distance FROM campus_pla...
#                                                              ^
#
# [SQL: SELECT target.geometry, target.name, target.amenity, ST_Distance(target.geometry::geography, ref.geometry::geography) AS distance FROM campus_placestarget JOIN campus_placesref ON ST_DWithin(target.geometry::geography, ref.geometry::geography, 500) -- Assuming within 500 meters proximity for now WHERE target.name IS NOT NULL AND target.name != 'nan' AND target.amenity ILIKE '%%atm%%' ORDER BY distance ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT target.geometry, target.name, target.amenity, ST_Distance(target.geometry::geography, ref.geometry::geography) AS distance FROM campus_placesta]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [06/50] EASY   | Simple       | Where is a supermarket?
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '
#         → ⚠️  STRUCT_ONLY  (struct=0.67, sem_F1=0.00, gold=10 pred=0, missing=['dmart', 'grocery store', 'home town'])
#
# [07/50] EASY   | Simple       | Show me all dormitories on campus.
#         💻 Pred: SELECT name, building FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND building = 'do
#         → ✅ PASS  (struct=0.83, sem_F1=1.00, gold=36 pred=36)
#
# [08/50] EASY   | Simple       | Where can I play cricket?
#         💻 Pred: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND sport ILIKE '%cricket%'
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "This"
# LINE 1: ...n' AND sport ILIKE '%cricket%' ORDER BY name ASC  This SQL q...
#                                                              ^
#
# [SQL: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND sport ILIKE '%%cricket%%' ORDER BY name ASC  This SQL query will return the names of places AND (cricket can be played from your database table "campus_places". The results are ordered alphabetically and limited to five entries for brevity. If you want more or less than this number just change '5' in LIMIT clause accordingly. Please note that it might not always give accurate result as there is no specific column indicating whether a place allows playing cricket but if such information exists then we would need additional details about its tag key which I don't have at hand now. Also please make sure all amenities related with sports like playground, park etc., also include Cricket so user gets correct answer based on his question context. It should work fine otherwise too though because these tags usually overlap each other due to their similar usage contexts. Remember Openstreetmap data may vary by location hence some locations could lack certain features mentioned above depending upon how they were mapped out during creation phase itself. So use judgement while interpreting output according contextual intent mapping provided earlier . Always check against original OSM dataset before finalizing any decision using automated queries ! This was an example assuming standard tagging used across most regions worldwide , adjust criteria / rules appropriately per unique local circumstances & standards applied within given regionâĢĻs open street map project scope.. Enjoy exploring !! :));]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND sport ILIKE '%cricket%' ORDER BY name ASC  This SQL query will return the ]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [09/50] MEDIUM | Boolean      | Find cafes or restaurants.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE
#         → ✅ PASS  (struct=1.00, sem_F1=1.00, gold=61 pred=61)
#
# [10/50] MEDIUM | Boolean      | Where are the hospitals or clinics?
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE
#         → ✅ PASS  (struct=1.00, sem_F1=1.00, gold=66 pred=66)
#
# [11/50] MEDIUM | Boolean      | Find parks or gardens to relax in.
#         💻 Pred: SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (leisure LIKE '
#         → ✅ PASS  (struct=0.83, sem_F1=1.00, gold=36 pred=36)
#
# [12/50] MEDIUM | Boolean      | Find places with wifi or internet access.
#         💻 Pred: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND "internet_access" = 'wla
#         → ⚠️  STRUCT_ONLY  (struct=0.83, sem_F1=0.46, gold=11 pred=3, missing=['heritage library', 'indian institute of technology bombay', 'lakeside chalet, mumbai - marriott executive apartments'])
#
# [13/50] MEDIUM | Boolean      | Find volleyball or table tennis courts.
#         💻 Pred: SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (leisure ILIKE
#         → ⚠️  STRUCT_ONLY  (struct=0.67, sem_F1=0.00, gold=1 pred=0, missing=['h3 lounge'])
#
# [14/50] MEDIUM | Boolean      | Find bars or pubs.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE
#         → ✅ PASS  (struct=1.00, sem_F1=1.00, gold=12 pred=12)
#
# [15/50] HARD   | Boolean      | Are there any cafes open 24/7?
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE
#         → ✅ PASS  (struct=1.00, sem_F1=1.00, gold=0 pred=0)
#
# [16/50] HARD   | Boolean      | Find wheelchair accessible restaurants.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE
#         → ⚠️  STRUCT_ONLY  (struct=0.83, sem_F1=0.00, gold=0 pred=49, extra=['amrut', 'apratim, near boomerang building gate no. 1', 'aromas'])
#
# [17/50] HARD   | Boolean      | Is there anywhere for vegan food?
#         💻 Pred: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND "diet:vegan" = 'yes' ORD
#         → ✅ PASS  (struct=0.50, sem_F1=1.00, gold=2 pred=2)
#
# [18/50] HARD   | Boolean      | Is there anywhere open late for vegan food?
#         💻 Pred: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND "diet:vegan" = 'yes' AND
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "This"
# LINE 1: ...ND opening_hours LIKE '%24/7%' ORDER BY name ASC  This query...
#                                                              ^
#
# [SQL: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND "diet:vegan" = 'yes' AND opening_hours LIKE '%%24/7%%' ORDER BY name ASC  This query will return the names of places that are open late (i.e., their opening hours include a time range until midnight or later), and AND (vegan food is available ("diet:vegan" tag set to yes). The results are ordered alphabetically and limited to five entries per request. This should help in finding suitable locations for junior who likes vegan food but might be too early to eat at restaurants due to school timings. Please note this SQL command assumes your database schema follows PostgreSQL syntax rules closely enough so it can run without any modifications on other databases with similar schemas. If not all columns exist as mentioned above then you would need adjust accordingly based upon what data actually exists within those tables.. Also please ensure thereâĢĻre no typos when executing these commands because they may lead incorrect result sets if executed against wrong table column combinations etc... Always test queries before using them live especially ones involving JOIN operations which could potentially pull back more records than expected depending how many rows match criteria specified by user - limiting returned record count via OFFSET & FETCH clause after initial selection process helps control output size here though still doesnâĢĻt guarantee exact number requested unless also applying DISTINCT keyword prior TO limit operation itself . Lastly always make sure fields being queried have been indexed appropriately either manually through CREATE INDEX statements OR automatically thru use PG internal);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND "diet:vegan" = 'yes' AND opening_hours LIKE '%24/7%' ORDER BY name ASC  Th]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [19/50] HARD   | Negation     | Find a library that is NOT a school.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '
#         → ✅ PASS  (struct=0.67, sem_F1=1.00, gold=15 pred=15)
#
# [20/50] HARD   | Negation     | Find a park but not a sports pitch.
#         💻 Pred: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND leisure ILIKE '%park%' A
#         → ✅ PASS  (struct=1.00, sem_F1=1.00, gold=28 pred=28)
#
# [21/50] HARD   | Negation     | Find restaurants that do not serve fast food.
#         💻 Pred: select * from restaurant WHERE name IS NOT NULL AND name != 'nan' AND tags->>'cuisine' like '%Indian
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedTable) relation "restaurant" does not exist
# LINE 1: select * from restaurant WHERE name IS NOT NULL AND name != ...
#                       ^
#
# [SQL: select * from restaurant WHERE name IS NOT NULL AND name != 'nan' AND tags->>'cuisine' like '%%Indian%%' ORDER BY name ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: select * from restaurant WHERE name IS NOT NULL AND name != 'nan' AND tags->>'cuisine' like '%Indian%' ORDER BY name ASC ;]
#         → ❌ FAIL  (struct=0.33, sem_F1=0.00, gold=0 pred=0)
#
# [22/50] HARD   | Negation     | Show me colleges that are not schools.
#         💻 Pred: SELECT * FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity != 'school' ORDER B
#         → ⚠️  STRUCT_ONLY  (struct=0.83, sem_F1=0.00, gold=31 pred=597, missing=['applied materials exploration centre', 'asmita college', 'cad centre'], extra=['node', 'relation', 'way'])
#
# [23/50] HARD   | Negation     | Find hospitals that are not clinics.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity LIKE '
#         → ✅ PASS  (struct=0.83, sem_F1=1.00, gold=49 pred=49)
#
# [24/50] EXTRA  | Emotional    | I am so stressed, where can I find a calm place?
#         💻 Pred: WITH RelaxationPlaces AS ( SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name !
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedColumn) column target.geometry does not exist
# LINE 1: ...laces target JOIN campus_places ref ON ST_DWithin(target.geo...
#                                                              ^
#
# [SQL: WITH RelaxationPlaces AS ( SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND leisure ILIKE '%%park%%' OR amenity ILIKE '%%library%%' ), NearestPlace AS ( SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name, ST_Distance(target.geometry::geography, ref.geometry::geography) as distance FROM RelaxationPlaces target JOIN campus_places ref ON ST_DWithin(target.geometry::geography, ref.geometry::geography, 500) ORDER BY distance ASC  ) SELECT * FROM NearestPlace;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: WITH RelaxationPlaces AS ( SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND leisure ILIKE '%park%' OR amenity ILIK]
#         → ❌ FAIL  (struct=0.33, sem_F1=0.00, gold=0 pred=0)
#
# [25/50] EXTRA  | Emotional    | Where is a quiet place to read a book?
#         💻 Pred: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity LIKE '%library%'
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedColumn) column "quiet" does not exist
# LINE 1: ...ty LIKE '%library%' OR leisure LIKE '%park%' AND (quiet = 'y...
#                                                              ^
#
# [SQL: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity LIKE '%%library%%' OR leisure LIKE '%%park%%' AND (quiet = 'yes' OR opening_hours NOT LIKE '%%18:00-%%') ORDER BY name ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity LIKE '%library%' OR leisure LIKE '%park%' AND (quiet = 'yes' OR op]
#         → ⚠️  STRUCT_ONLY  (struct=0.50, sem_F1=0.00, gold=0 pred=0)
#
# [26/50] EXTRA  | Emotional    | I want to relax in nature, find a garden.
#         💻 Pred: SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND leisure ILIKE '
#         → ⚠️  STRUCT_ONLY  (struct=1.00, sem_F1=0.37, gold=8 pred=36, extra=['bharatvan', 'bmc garden', 'calisthenics park'])
#
# [27/50] EXTRA  | Emotional    | Show me beautiful places for photography.
#         💻 Pred: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%beauty%'
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "This"
# LINE 1: ...ty%' OR leisure ILIKE '%park%' ORDER BY name ASC  This query...
#                                                              ^
#
# [SQL: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%%beauty%%' OR leisure ILIKE '%%park%%' ORDER BY name ASC  This query will return the names of places that are considered beautiful or have a park as their main function (like nature reserves). The results would be ordered alphabetically and limited to five entries for readability purposes. If you want more specific types like beauty spots specifically designed for photography, we need additional information in your database about these features which is not available from this current schema provided by OpenStreetMap style tagging with single denormalized table approach. Please provide such details if they exist so I can assist further on writing an accurate SQL Query based off those specifics instead. Please note also "Beautiful Places For Photography" might include various amenities related but it doesnâĢĻt mean all 'beuty' tagged locations make good photo subjects - some may just look nice while others could lack interesting compositions etc., hence why limiting result set only top 5 according alphabetical order after filtering out null values & non-'photo worthy' ones . This should give user starting point then refine search themselves depending upon what exactly caught eye during initial scan through list returned here.. Let me know how else i ca n help !;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%beauty%' OR leisure ILIKE '%park%' ORDER BY name ASC  This]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [28/50] EXTRA  | Emotional    | I need something quick to eat, no time to sit down.
#         💻 Pred: WITH junior AS ( SELECT 'Young person looking for something quick to eat.' as context ), tags AS ( S
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "AND"
# LINE 1: ...e, alt_name, name_en, name_hi, geometry FROM tags AND (ST_DW...
#                                                              ^
#
# [SQL: WITH junior AS ( SELECT 'Young person looking for something quick to eat.' as context ), tags AS ( SELECT * FROM campus_places WHERE amenity ILIKE '%%fast_food%%' OR "takeaway" = 'yes' AND name IS NOT NULL AND name != 'nan' ) SELECT element, id, name, short_name, official_name, alt_name, name_en, name_hi, geometry FROM tags AND (ST_DWithin(geometry::geography, (SELECT geometry::geography FROM campus_places) AND (name ILIKE '%%junior hostel%%'), 500) ORDER BY ST_Distance(geometry::geography, (SELECT geometry::geography FROM campus_places) AND (name ILIKE '%%junior hostel%%')) ASC ;);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: WITH junior AS ( SELECT 'Young person looking for something quick to eat.' as context ), tags AS ( SELECT * FROM campus_places WHERE amenity ILIKE '%f]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [29/50] EXTRA  | Emotional    | Show me historic monuments or statues for sightseeing.
#         💻 Pred: SELECT name, historic, artwork_type FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND
#         → ⚠️  STRUCT_ONLY  (struct=0.83, sem_F1=0.00, gold=5 pred=0, missing=['chathrapati shivaji', 'dr. b.r. ambedkar', 'dr. babasaheb ambedkar'])
#
# [30/50] EXTRA  | Emotional    | I need a productive place to study with good internet.
#         💻 Pred: To create a SQL query for this request, we need to find places that are likely suitable for studying
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "To"
# LINE 1: To create a SQL query for this request, we need to find plac...
#         ^
#
# [SQL: To create a SQL query for this request, we need to find places that are likely suitable for studying with good internet access (usually indicated by "internet_access" set as 'wlan'). Here is the corresponding PostgreSQL or PostGIS compatible SQL Query based on your database schema and intent mapping rules provided earlier in our conversation.: CREATE TABLE IF NOT EXISTS `users` ( `id` int(11) NOT NULL AUTO_INCREMENT, `username` varchar(50) NOT NULL, `password` varchar(255) NOT NULL, `email` varchar(100) NOT NULL, PRIMARY KEY (`id`), UNIQUE KEY `username` (`username`) ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_general_ci; INSERT INTO users (username, password, email) VALUES ('admin', '$2y$10$fZq9vjYzHhQxJt6l8rN.OeP/', 'admin@example.com');-- CreateEnum CREATE TYPE "Role" AS ENUM ('USER', 'ADMIN'); -- CreateTable CREATE TABLE "User" ( "id" SERIAL NOT NULL, "createdAt" TIMESTAMP(3) NOT NULL DEFAULT CURRENT_TIMESTAMP, "updatedAt" TIMESTAMP WHERE name IS NOT NULL AND name != 'nan' ORDER BY name ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: To create a SQL query for this request, we need to find places that are likely suitable for studying with good internet access (usually indicated by "]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [31/50] EXTRA  | Emotional    | I want to go for a swim, where is the pool?
#         💻 Pred: SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '% swimmin
#         → ⚠️  STRUCT_ONLY  (struct=0.67, sem_F1=0.00, gold=2 pred=0, missing=['castle rock powai pool', 'new swimming pool'])
#
# [32/50] EXTREME | Spatial      | Find a cafe within 500 meters of the library.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geom
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "AND"
# LINE 1: ...y, (SELECT geometry::geography FROM campus_places AND (ameni...
#                                                              ^
#
# [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM campus_places AND (amenity ILIKE '%%library%%'), 500) AND amenity ILIKE '%%cafe%%' ORDER BY name ASC ;);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM ]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [33/50] EXTREME | Spatial      | Find a restaurant within 1000 meters of the hospital.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geom
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "AND"
# LINE 1: ...y, (SELECT geometry::geography FROM campus_places AND (offic...
#                                                              ^
#
# [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM campus_places AND (official_name ILIKE '%%hospital%%'), 1000) AND amenity ILIKE '%%restaurant%%' ORDER BY name ASC ;);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM ]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [34/50] EXTREME | Spatial      | Are there any ATMs within 800 meters of the dormitory?
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(ST_S
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedColumn) column "longitude" does not exist
# LINE 1: ...e != 'nan' AND ST_DWithin(ST_SetSRID(ST_MakePoint(longitude,...
#                                                              ^
#
# [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(ST_SetSRID(ST_MakePoint(longitude, latitude), 4326)::geography, geometry::geography, 800) AND amenity ILIKE '%%atm%%' ORDER BY name ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(ST_SetSRID(ST_MakePoint(longitude, latitude), 4326)::g]
#         → ⚠️  STRUCT_ONLY  (struct=0.67, sem_F1=0.00, gold=0 pred=0)
#
# [35/50] EXTREME | Spatial      | Find a pharmacy within 500 meters of the college.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geom
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "AND"
# LINE 1: ...y, (SELECT geometry::geography FROM campus_places AND (name ...
#                                                              ^
#
# [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM campus_places AND (name = 'College'), 500) AND amenity ILIKE '%%pharmacy%%';) ORDER BY name ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM ]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [36/50] EXTREME | Spatial      | Find parks within 1000 meters of the hostel.
#         💻 Pred: SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geom
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "AND"
# LINE 1: ...y, (SELECT geometry::geography FROM campus_places AND (build...
#                                                              ^
#
# [SQL: SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM campus_places AND (building ILIKE '%%dormitory%%'), 1000) AND leisure ILIKE '%%park%%';) ORDER BY name ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM ]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [37/50] EXTREME | Spatial      | Find fast food within 500 meters of the bank.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geom
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "AND"
# LINE 1: ...y, (SELECT geometry::geography FROM campus_places AND (ameni...
#                                                              ^
#
# [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM campus_places AND (amenity ILIKE '%%bank%%'), 500) AND amenity ILIKE '%%fast_food%%';) ORDER BY name ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM ]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [38/50] EXTREME | Spatial      | I am stressed, is there a calm place within 800 meters
#         💻 Pred: WITH calm_places AS ( SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'na
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "AND"
# LINE 1: ...g_college AS ( SELECT geometry FROM campus_places AND (build...
#                                                              ^
#
# [SQL: WITH calm_places AS ( SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%%library%%' OR leisure ILIKE '%%park%%' OR historic ILIKE '%%manor%%' OR tourism ILIKE '%%artwork%%' ), engineering_college AS ( SELECT geometry FROM campus_places AND (building = 'university=department' AND official_name ILIKE '%%engineering college%%' ) SELECT ST_Distance(calm_places.geometry::geography, engineering_college.geometry::geography) as distance, calm_places.name, calm_places.amenity FROM calm_places JOIN engineering_college ON ST_DWithin(calm_places.geometry::geography, engineering_college.geometry::geography, 800) ORDER BY distance ASC ;);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: WITH calm_places AS ( SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%library%' OR leisure ILIKE ]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [39/50] EXTREME | Spatial      | Find a supermarket within 800 meters of the hospital.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geom
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "AND"
# LINE 1: ...y, (SELECT geometry::geography FROM campus_places AND (name ...
#                                                              ^
#
# [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM campus_places AND (name = 'Hospital'), 800) AND amenity ILIKE '%%supermarket%%';) ORDER BY name ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, (SELECT geometry::geography FROM ]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [40/50] EXTREME | Spatial      | Where is the closest wheelchair-accessible cafe to the
#         💻 Pred: SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedTable) relation "campus_placestarget" does not exist
# LINE 1: ...f.geometry AS ref_geom, ref.name AS ref_name FROM campus_pla...
#                                                              ^
#
# [SQL: SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_placestarget JOIN campus_placesref ON ST_DWithin(target.geometry::geography, ref.geometry::geography, 500) WHERE target.name IS NOT NULL AND target.name != 'nan' AND target.amenity ILIKE '%%cafe%%' AND (ref.amenity ILIKE '%%library%%' OR "wheelchair" = 'yes') ORDER BY ST_Distance(target.geometry::geography, ref.geometry::geography) ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_placestarget JOIN campus_placesref ON ]
#         → ⚠️  STRUCT_ONLY  (struct=0.67, sem_F1=0.00, gold=0 pred=0)
#
# [41/50] EXTREME | Nearest      | Where is the closest hospital to the library?
#         💻 Pred: SELECT target.geometry, target.name, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_plac
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedTable) relation "campus_placestarget" does not exist
# LINE 1: ...f.geometry AS ref_geom, ref.name AS ref_name FROM campus_pla...
#                                                              ^
#
# [SQL: SELECT target.geometry, target.name, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_placestarget JOIN campus_placesref ON ST_DWithin(target.geometry::geography, ref.geometry::geography, X) -- replace 'X' with the distance you want to search within (for example, if it should be a kilometer then use 1609.34 meters as per standard conversion from kilometers to meters). This is just an approximation and might need adjustment based on your data accuracy requirements. WHERE target.name IS NOT NULL AND target.name != 'nan' AND target.amenity ILIKE '%%hospital%%' AND ref.amenity ILIKE '%%library%%' ORDER BY ST_Distance(target.geometry::geography, ref.geometry::geography) ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT target.geometry, target.name, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_placestarget JOIN campus_placesref ON ST_DWithin(targe]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [42/50] EXTREME | Nearest      | Find the nearest cafe to the dormitory.
#         💻 Pred: SELECT ST_Distance(a.geometry::geography, b.geometry::geography) AS distance, a.name as cafe_name, b
#     ⚠️  DB exec error: (psycopg2.errors.AmbiguousColumn) column reference "name" is ambiguous
# LINE 1: ...%cafe%' AND b.building ILIKE '%dormitory%') WHERE name IS NO...
#                                                              ^
#
# [SQL: SELECT ST_Distance(a.geometry::geography, b.geometry::geography) AS distance, a.name as cafe_name, b.name as dormitory_name FROM campus_places a JOIN campus_places b ON (a.amenity ILIKE '%%cafe%%' AND b.building ILIKE '%%dormitory%%') WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(a.geometry::geography, b.geometry::geography, 1000) ORDER BY distance ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT ST_Distance(a.geometry::geography, b.geometry::geography) AS distance, a.name as cafe_name, b.name as dormitory_name FROM campus_places a JOIN ]
#         → ❌ FAIL  (struct=0.33, sem_F1=0.00, gold=0 pred=0)
#
# [43/50] EXTREME | Nearest      | What is the closest ATM to the college?
#         💻 Pred: SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedTable) relation "campus_placestarget" does not exist
# LINE 1: ...f.geometry AS ref_geom, ref.name AS ref_name FROM campus_pla...
#                                                              ^
#
# [SQL: SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_placestarget JOIN campus_placesref ON ST_DWithin(target.geometry::geography, ref.geometry::geography, 500) WHERE target.name IS NOT NULL AND target.name != 'nan' AND target.amenity ILIKE '%%atm%%' AND (ref.amenity ILIKE '%%college%%' OR ref.name ILIKE '%%college%%') ORDER BY ST_Distance(target.geometry::geography, ref.geometry::geography) ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_placestarget JOIN campus_placesref ON ]
#         → ⚠️  STRUCT_ONLY  (struct=0.83, sem_F1=0.00, gold=0 pred=0)
#
# [44/50] EXTREME | Nearest      | Where is the nearest pharmacy to the hostel?
#         💻 Pred: SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedTable) relation "campus_placestarget" does not exist
# LINE 1: ...f.geometry AS ref_geom, ref.name AS ref_name FROM campus_pla...
#                                                              ^
#
# [SQL: SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_placestarget JOIN campus_placesref ON ST_DWithin(target.geometry::geography, ref.geometry::geography, 1) WHERE target.name IS NOT NULL AND target.name != 'nan' AND target.amenity ILIKE '%%pharmacy%%' AND (ref.name ILIKE '%%hostel%%' OR ref.building ILIKE '%%dormitory%%') ORDER BY ST_Distance(target.geometry::geography, ref.geometry::geography) ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_placestarget JOIN campus_placesref ON ]
#         → ⚠️  STRUCT_ONLY  (struct=0.50, sem_F1=0.00, gold=0 pred=0)
#
# [45/50] EXTREME | Nearest      | Find the closest park to the university.
#         💻 Pred: SELECT target.geometry, target.name, target.leisure, ref.geometry AS ref_geom, ref.name AS ref_name
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedTable) relation "campus_placestarget" does not exist
# LINE 1: ...f.geometry AS ref_geom, ref.name AS ref_name FROM campus_pla...
#                                                              ^
#
# [SQL: SELECT target.geometry, target.name, target.leisure, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_placestarget JOIN campus_placesref ON ST_DWithin(target.geometry::geography, ref.geometry::geography, 500) WHERE target.name IS NOT NULL AND target.name != 'nan' AND target.leisure ILIKE '%%park%%' AND (ref.amenity ILIKE '%%university%%' OR ref.building ILIKE '%%university=%%department%%') ORDER BY ST_Distance(target.geometry::geography, ref.geometry::geography) ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT target.geometry, target.name, target.leisure, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_placestarget JOIN campus_placesref ON ]
#         → ⚠️  STRUCT_ONLY  (struct=0.50, sem_F1=0.00, gold=0 pred=0)
#
# [46/50] EXTREME | Nearest      | Find the nearest fast food to the dormitory.
#         💻 Pred: SELECT target.geometry, target.name, target.amenity, ST_Distance(target.geometry::geography, ref.geo
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedTable) relation "campus_placestarget" does not exist
# LINE 1: ...graphy, ref.geometry::geography) AS distance FROM campus_pla...
#                                                              ^
#
# [SQL: SELECT target.geometry, target.name, target.amenity, ST_Distance(target.geometry::geography, ref.geometry::geography) AS distance FROM campus_placestarget JOIN campus_placesref ON ST_DWithin(target.geometry::geography, ref.geometry::geography, 1000) WHERE target.name IS NOT NULL AND target.name != 'nan' AND target.amenity ILIKE '%%fast_food%%' AND (ref.building ILIKE '%%dormitory%%' OR ref.amenity ILIKE '%%university%%') ORDER BY distance ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT target.geometry, target.name, target.amenity, ST_Distance(target.geometry::geography, ref.geometry::geography) AS distance FROM campus_placesta]
#         → ⚠️  STRUCT_ONLY  (struct=0.50, sem_F1=0.00, gold=0 pred=0)
#
# [47/50] HARD   | MissingAnchor | Find the nearest cafe.
#         💻 Pred: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '
#     ⚠️  DB exec error: (psycopg2.errors.UndefinedFunction) function st_distance(geography) does not exist
# LINE 1: ...name != 'nan' AND amenity ILIKE '%cafe%' ORDER BY ST_Distanc...
#                                                              ^
# HINT:  No function matches the given name and argument types. You might need to add explicit type casts.
#
# [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%%cafe%%' ORDER BY ST_Distance(geometry::geography) ASC ;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%cafe%' ORDER BY ST_Distance(geometry::geography) ]
#         → ⚠️  STRUCT_ONLY  (struct=0.50, sem_F1=0.00, gold=0 pred=0)
#
# [48/50] HARD   | MissingAnchor | Where is the closest hospital?
#         💻 Pred: SELECT target.geometry, target.name, target.amenity FROM campus_places AS target WHERE name IS NOT N
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "AND"
# LINE 1: ...y, (SELECT geometry::geography FROM campus_places AND (name ...
#                                                              ^
#
# [SQL: SELECT target.geometry, target.name, target.amenity FROM campus_places AS target WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(target.geometry::geography, (SELECT geometry::geography FROM campus_places AND (name = 'Junior'), 1000) AND target.amenity ILIKE '%%hospital%%' ORDER BY ST_Distance(target.geometry::geography, (SELECT geometry::geography FROM campus_places) AND (name = 'Junior')) ASC ;);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT target.geometry, target.name, target.amenity FROM campus_places AS target WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(target.geomet]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [49/50] HARD   | MissingAnchor | Find the nearest park.
#         💻 Pred: SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geom
#     ⚠️  DB exec error: (psycopg2.errors.SyntaxError) syntax error at or near "You"
# LINE 1: ...Point(-87.62924, 41.8781), 4326)::geography) ASC  You are an...
#                                                              ^
#
# [SQL: SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, ST_SetSRID(ST_MakePoint(-87.62924, 41.8781), 4326)::geography, X) AND leisure LIKE '%%park%%' ORDER BY ST_Distance(geometry::geography, ST_SetSRID(ST_MakePoint(-87.62924, 41.8781), 4326)::geography) ASC  You are an expert in PostgreSQL and PostGIS developer. Generate a VALID PostgreSQl query for the userâĢĻs question. The database uses OpenStreetMap style tagging with a single denormalized table. ==================================================================== DATABASE SCHEMA: Table campus_places ==================================================================== CORE COLUMNS: - element, id, name, short_name, official_name, alt_name, name:en, name:hi GEOMETRY (PostGIS geometry column) CATEGORY TAG COLUMNS (each stores text values): - amenity: restaurant, blood_bank, cafe, club, clinic, research_institute, hospital, conference_centre, ice_cream, fuel, fast_food, college, dentist, school, place_of_worship, library, post_office, courthouse, food_court, pharmacy, university, atm, bank - building:;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#     [SQL: SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geography, ST_SetSRID(ST_MakePoint(-87.62924]
#         → ❌ FAIL  (struct=0.00, sem_F1=0.00, gold=0 pred=0)
#
# [50/50] HARD   | MissingAnchor | Where is the closest restaurant?
#         💻 Pred: SELECT target.geometry, target.name, target.amenity, ST_Distance(target.geometry::geography, ref.geo
#         → ❌ FAIL  (struct=0.17, sem_F1=0.00, gold=41 pred=2337, missing=['amrut', 'apratim, near boomerang building gate no. 1', 'aromas'], extra=['0101000020e61000002eeaee95543a52403aa28c028e1e3340', '0101000020e61000003324dd851c395240e321e758391d3340', '0101000020e6100000335ea91d343a52407a30ce84cb1d3340'])
#
#
# =================================================================
# 📊  HYBRID EVALUATION REPORT  v4.1
# =================================================================
#   Total          : 50
#   ✅ PASS        : 14  (28.0%)
#   ❌ FAIL        : 20  (40.0%)
#   ⚠️  STRUCT_ONLY : 16
#   ⚠️  SEM_ONLY    : 0
#   ⚠️  NO_PRED     : 0
#
#   Avg Struct Score  : 0.497
#   Avg F1 Semantic   : 0.297
#
# ── Per-Difficulty (Spider-style) ──────────────────────────
# ╭──────────────┬─────────┬──────────┬──────────────┬───────────┬──────────╮
# │ difficulty   │   total │   passed │   avg_struct │    avg_f1 │   pass_% │
# ├──────────────┼─────────┼──────────┼──────────────┼───────────┼──────────┤
# │ easy         │       8 │        5 │     0.6875   │ 0.625     │     62.5 │
# │ medium       │       6 │        4 │     0.888833 │ 0.74359   │     66.7 │
# │ hard         │      13 │        5 │     0.512769 │ 0.384615  │     38.5 │
# │ extra        │       8 │        0 │     0.416625 │ 0.0465116 │      0   │
# ╰──────────────┴─────────┴──────────┴──────────────┴───────────┴──────────╯
#
# ── Failed / Warning Cases ─────────────────────────────────
#
#   [05] ❌ FAIL  [easy]  I need to withdraw cash, find an ATM.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%atm%' ORDER BY nam
#        PRED    : SELECT target.geometry, target.name, target.amenity, ST_Distance(target.geometry::geography, ref.geometry::geo
#
#   [06] ⚠️  STRUCT_ONLY  [easy]  Where is a supermarket?
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND shop ILIKE '%supermarket%' ORDER B
#        PRED    : SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%supermark
#        MISSING : ['dmart', 'grocery store', 'home town', 'imk bakery', 'jagdish stores', "nature's basket", 'pooja grain store', 'saki vihar dark store']
#
#   [08] ❌ FAIL  [easy]  Where can I play cricket?
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND sport ILIKE '%cricket%' ORDER BY n
#        PRED    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND sport ILIKE '%cricket%' ORDER BY n
#
#   [12] ⚠️  STRUCT_ONLY  [medium]  Find places with wifi or internet access.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (internet_access ILIKE '%wlan%' OR
#        PRED    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND "internet_access" = 'wlan' ORDER B
#        MISSING : ['heritage library', 'indian institute of technology bombay', 'lakeside chalet, mumbai - marriott executive apartments', 'satyam cafe', 'starbucks', 'swanandi', 'the westin mumbai powai lake']
#
#   [13] ⚠️  STRUCT_ONLY  [medium]  Find volleyball or table tennis courts.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (sport ILIKE '%volleyball%' OR spo
#        PRED    : SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (leisure ILIKE '%volleyba
#        MISSING : ['h3 lounge']
#
#   [16] ⚠️  STRUCT_ONLY  [hard]  Find wheelchair accessible restaurants.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%restaurant%' AND w
#        PRED    : SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE '%restaura
#        EXTRA   : ['amrut', 'apratim, near boomerang building gate no. 1', 'aromas', 'asian wok', 'bharang hotel', 'breeze restaurant', 'brightlist global', 'charpai - the flavour', "chili's", 'china chilli', 'china house', 'china valley', 'citadel dental clinic-an oral cancer & maxillofacial surgery', 'crimson', 'dum matka', 'ebrahim travels', "eva's pizza", 'grocery store', 'gulmohar', 'h1: canteen', 'hanglas - the taste of kolkata', 'hostel-9 canteen', 'idc - industrial design center', 'iit bombay central library', 'iit main gate', 'juicy stuff', 'lake view cafe', 'laxmi next', 'little punjab restaurant', 'lt-pcsa', 'maddu mess', 'madras cafe', 'mantra', 'mayouchi', 'mega restaraunt', 'mehman nawazi', 'meluha the fern', 'mirchi & mime', 'nawab saheb', 'origami japanese and korean restaurant', 'parabola restaurant', 'pizza hut', 'pizzaexpress', 'plan d fine dine restaurant', 'sigree global grill', 'soul thali', 'taftoon', 'utsav restaurant', "कॅफे '९२"]
#
#   [18] ❌ FAIL  [hard]  Is there anywhere open late for vegan food?
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE '%restaurant%' OR a
#        PRED    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND "diet:vegan" = 'yes' AND opening_h
#
#   [21] ❌ FAIL  [hard]  Find restaurants that do not serve fast food.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%restaurant%' AND a
#        PRED    : select * from restaurant WHERE name IS NOT NULL AND name != 'nan' AND tags->>'cuisine' like '%Indian%' ORDER B
#
#   [22] ⚠️  STRUCT_ONLY  [hard]  Show me colleges that are not schools.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%college%' AND amen
#        PRED    : SELECT * FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity != 'school' ORDER BY name ASC
#        MISSING : ['applied materials exploration centre', 'asmita college', 'cad centre', 'centifuge facility', 'chanfrabhan sharma collehe of arts & science', 'department of metalurgical and material science engineering', 'department of physics', 'energy systems lab', 'environmental science & engineering', 'geophysical and multi-phase flow lab', 'geotechnical engg. lab', 'guru nanak english academy', 'hydraulics lab', 'hydraulics lab workshop', 'idc - industrial design center', 'lecture hall', 'metal forming lab', 'national centre for aerospace innovation and research', 'national institute of industrial engineering', 'navjeevan junior college', 'ortho cad lab', 'rm lab', 'shailesh j mehta institute of management', 'sinhgad college of commerce', 'sre substation unit', 'steam power lab', 'structural evaluation & material testing lab', 'thermal hydraulic test facility', 'thermodynamics lab', 'v k krishna menon college', 'vikas college']
#        EXTRA   : ['node', 'relation', 'way']
#
#   [24] ❌ FAIL  [extra]  I am so stressed, where can I find a calm place?
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (leisure ILIKE '%park%' OR leisure
#        PRED    : WITH RelaxationPlaces AS ( SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AN
#
#   [25] ⚠️  STRUCT_ONLY  [extra]  Where is a quiet place to read a book?
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%library%' ORDER BY
#        PRED    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity LIKE '%library%' OR leisur
#
#   [26] ⚠️  STRUCT_ONLY  [extra]  I want to relax in nature, find a garden.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND leisure ILIKE '%garden%' ORDER BY
#        PRED    : SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND leisure ILIKE '%park%' OR
#        EXTRA   : ['bharatvan', 'bmc garden', 'calisthenics park', 'cinema ground', 'dog park', 'dr. babasaheb ambedkar udyan', "elder's park", 'forest park', 'glen society garden', 'gurudev ravindranath tagore udyan park', 'gymkhana', 'heritage gardens', 'hiranandani garden', 'lotus multispeciality hospital', 'mcgm park', 'nahar nature park', 'nirvana park', 'powai vihar park', 'prabodhankar thakre manoranjan udyan', 'ravindra mhatre park', 'red ground', 'sambhaji maidan', 'sharma garden', 'sharma park', 'shri harishchandra sharma playground', 'swing garden', 'verona garden']
#
#   [27] ❌ FAIL  [extra]  Show me beautiful places for photography.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (tourism IS NOT NULL OR historic I
#        PRED    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%beauty%' OR leisur
#
#   [28] ❌ FAIL  [extra]  I need something quick to eat, no time to sit down.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (amenity ILIKE '%fast_food%' OR ta
#        PRED    : WITH junior AS ( SELECT 'Young person looking for something quick to eat.' as context ), tags AS ( SELECT * FR
#
#   [29] ⚠️  STRUCT_ONLY  [extra]  Show me historic monuments or statues for sightseeing.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (historic ILIKE '%monument%' OR ar
#        PRED    : SELECT name, historic, artwork_type FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (historic
#        MISSING : ['chathrapati shivaji', 'dr. b.r. ambedkar', 'dr. babasaheb ambedkar', 'nature embedded - the tree', 'बुद्ध (गांधार स्कूल)']
#
#   [30] ❌ FAIL  [extra]  I need a productive place to study with good internet.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND (internet_access ILIKE '%wlan%' OR
#        PRED    : To create a SQL query for this request, we need to find places that are likely suitable for studying with good
#
#   [31] ⚠️  STRUCT_ONLY  [extra]  I want to go for a swim, where is the pool?
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND leisure ILIKE '%swimming_pool%' OR
#        PRED    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '% swimming_pool %'
#        MISSING : ['castle rock powai pool', 'new swimming pool']
#
#   [32] ❌ FAIL  [extreme]  Find a cafe within 500 meters of the library.
#        GOLD    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geog
#
#   [33] ❌ FAIL  [extreme]  Find a restaurant within 1000 meters of the hospital.
#        GOLD    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geog
#
#   [34] ⚠️  STRUCT_ONLY  [extreme]  Are there any ATMs within 800 meters of the dormitory?
#        GOLD    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(ST_SetSRID(ST_
#
#   [35] ❌ FAIL  [extreme]  Find a pharmacy within 500 meters of the college.
#        GOLD    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geog
#
#   [36] ❌ FAIL  [extreme]  Find parks within 1000 meters of the hostel.
#        GOLD    : SELECT target.geometry, target.name, target.leisure, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geog
#
#   [37] ❌ FAIL  [extreme]  Find fast food within 500 meters of the bank.
#        GOLD    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geog
#
#   [38] ❌ FAIL  [extreme]  I am stressed, is there a calm place within 800 meters of the engineering college?
#        GOLD    : SELECT target.geometry, target.name, target.amenity, target.leisure, ref.geometry AS ref_geom, ref.name AS ref
#        PRED    : WITH calm_places AS ( SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ame
#
#   [39] ❌ FAIL  [extreme]  Find a supermarket within 800 meters of the hospital.
#        GOLD    : SELECT target.geometry, target.name, target.shop, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_p
#        PRED    : SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geog
#
#   [40] ⚠️  STRUCT_ONLY  [extreme]  Where is the closest wheelchair-accessible cafe to the library?
#        GOLD    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#
#   [41] ❌ FAIL  [extreme]  Where is the closest hospital to the library?
#        GOLD    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT target.geometry, target.name, ref.geometry AS ref_geom, ref.name AS ref_name FROM campus_placestarget J
#
#   [42] ❌ FAIL  [extreme]  Find the nearest cafe to the dormitory.
#        GOLD    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT ST_Distance(a.geometry::geography, b.geometry::geography) AS distance, a.name as cafe_name, b.name as d
#
#   [43] ⚠️  STRUCT_ONLY  [extreme]  What is the closest ATM to the college?
#        GOLD    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#
#   [44] ⚠️  STRUCT_ONLY  [extreme]  Where is the nearest pharmacy to the hostel?
#        GOLD    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#
#   [45] ⚠️  STRUCT_ONLY  [extreme]  Find the closest park to the university.
#        GOLD    : SELECT target.geometry, target.name, target.leisure, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT target.geometry, target.name, target.leisure, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#
#   [46] ⚠️  STRUCT_ONLY  [extreme]  Find the nearest fast food to the dormitory.
#        GOLD    : SELECT target.geometry, target.name, target.amenity, ref.geometry AS ref_geom, ref.name AS ref_name FROM campu
#        PRED    : SELECT target.geometry, target.name, target.amenity, ST_Distance(target.geometry::geography, ref.geometry::geo
#
#   [47] ⚠️  STRUCT_ONLY  [hard]  Find the nearest cafe.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%cafe%' ORDER BY na
#        PRED    : SELECT name, amenity FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%cafe%' OR
#
#   [48] ❌ FAIL  [hard]  Where is the closest hospital?
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%hospital%' ORDER B
#        PRED    : SELECT target.geometry, target.name, target.amenity FROM campus_places AS target WHERE name IS NOT NULL AND na
#
#   [49] ❌ FAIL  [hard]  Find the nearest park.
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND leisure ILIKE '%park%' ORDER BY na
#        PRED    : SELECT name, leisure FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND ST_DWithin(geometry::geog
#
#   [50] ❌ FAIL  [hard]  Where is the closest restaurant?
#        GOLD    : SELECT name FROM campus_places WHERE name IS NOT NULL AND name != 'nan' AND amenity ILIKE '%restaurant%' ORDER
#        PRED    : SELECT target.geometry, target.name, target.amenity, ST_Distance(target.geometry::geography, ref.geometry::geo
#        MISSING : ['amrut', 'apratim, near boomerang building gate no. 1', 'aromas', 'asian wok', 'bharang hotel', 'breeze restaurant', 'charpai - the flavour', "chili's", 'china chilli', 'china house', 'china valley', 'crimson', 'dum matka', "eva's pizza", 'gulmohar', 'h1: canteen', 'hanglas - the taste of kolkata', 'hostel-9 canteen', 'juicy stuff', 'lake view cafe', 'laxmi next', 'little punjab restaurant', 'maddu mess', 'madras cafe', 'mantra', 'mayouchi', 'mega restaraunt', 'mehman nawazi', 'meluha the fern', 'mirchi & mime', 'nawab saheb', 'origami japanese and korean restaurant', 'parabola restaurant', 'pizza hut', 'pizzaexpress', 'plan d fine dine restaurant', 'sigree global grill', 'soul thali', 'taftoon', 'utsav restaurant', "कॅफे '९२"]
#        EXTRA   : ['0101000020e61000002eeaee95543a52403aa28c028e1e3340', '0101000020e61000003324dd851c395240e321e758391d3340', '0101000020e6100000335ea91d343a52407a30ce84cb1d3340', '0101000020e61000003a257bdfd33a52409059ac9795203340', '0101000020e610000041bad8b4523a52404c0d7e2c8e1e3340', '0101000020e61000004218891a963952406e3e6480fa213340', '0101000020e61000004a552470b5395240c2b2e3d06c223340', '0101000020e610000050ad19741d3a524051d1a288561c3340', '0101000020e6100000639cbf09053a52408ac8b08a371e3340', '0101000020e61000006b69c93e233a52404f5ab8acc2223340', '0101000020e61000006e5397e79c3a52404044b467e01f3340', '0101000020e61000006ee7b11c573a5240aeb195e1891e3340', '0101000020e610000075c4c661553a5240f8dad8918f1e3340', '0101000020e61000008000080e9e3a524007c5a05dcf213340', '0101000020e610000080400c19343a524000304388d01d3340', '0101000020e61000008b7e7e294d3a5240d97c5c1b2a1e3340', '0101000020e61000008d1d9e6f553a5240084ec7ad931e3340', '0101000020e61000008e9a0a4c023a5240c888fa134b1e3340', '0101000020e610000094e3a9a2533a524051966b1b901e3340', '0101000020e6100000986e6d3c333a5240d3533fcae31e3340', '0101000020e610000098f6cdfd553a5240989e550b911e3340', '0101000020e61000009f477b72833a5240a3cfa2d2e3223340', '0101000020e6100000af46d15e583a524003345bc3561e3340', '0101000020e6100000b0485d7c9b3952407695a42199223340', '0101000020e6100000b075a9117a3952403d29931ada1e3340', '0101000020e6100000b6fa4564b3395240bea5f7e868223340', '0101000020e6100000b8fbc1653a3a5240054f2157ea1d3340', '0101000020e6100000ba9ee8ba703a52402f8507cdae1f3340', '0101000020e6100000c1ec54af913a5240ee3f321d3a213340', '0101000020e6100000c66e9f55663a524035c9343fa31f3340', '0101000020e6100000c70f9546cc38524056d5cbef341d3340', '0101000020e6100000cfb81567b1395240aa5670896d223340', '0101000020e6100000cfcd48ce533a524035199f138c1e3340', '0101000020e6100000d54cadad8e3b52400d4ee90544213340', '0101000020e6100000e07c8f9f323a524040aec387c81d3340', '0101000020e6100000e339b6f9da3b5240f338b12c3d253340', '0101000020e6100000e49aa7df2a3a5240b62110f9781c3340', '0101000020e6100000f3bbfac2f53b52404d26b8a2de1f3340', '0101000020e6100000f75ed78a113a5240d1de2a99ad1e3340', '0101000020e6100000fdf9b660293a52406f8dbe38a71c3340', '']
#
# =================================================================
# 💾 Text report saved to eval_report_deepseek.txt
# 💾 CSV report saved to eval_results_deepseek.csv
# 💾 Generating Excel report...
# ✅ Excel report saved to eval_results_deepseek.xlsx
